# %% [markdown]
# <a href="https://colab.research.google.com/github/sedataskinoglu/functions_exercise_2/blob/main/Liste_disct_odev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ödev 1
#
# liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]
#
# 1. Aşağıdaki işlemleri indexing ve slicing kullanarak liste üzerinde uygulayın.
#
#    - "3" değerine ulaşmak için indexleme yapın.
#    - "Hi-Kod" değerine ulaşmak için indexleme yapın.
#    - 4.7 değerine ulaşmak için indexleme yapın.
#    - 9,"3",8.4,"Hi-Kod" değerlerine ulaşmak için slicing yapın.
#    - 8.4,"Hi-Kod","False",4.7 değerlerine ulaşmak için slicing yapın.

# %%
liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]
print(liste[3])
print(liste[5])
print(liste[-1])
print(liste[2:5])
print(liste[4:])
# Out:
# 3
# Hi-Kod
# 4.7
# [9, '3', 8.4]
# [8.4, 'Hi-Kod', 'False', 4.7]

# %% [markdown]
# ### Ödev 2
#
# Verilen listede bulunan string veri tipindeki öğeleri yeni_liste isimli listeye eklenir.
#
# liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]

# %%
liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]
yeni_liste = []

for i in liste:
  if type(i) == str:
    yeni_liste.append(i)
yeni_liste
# Out:
# ['Python', '3', 'Hi-Kod', 'False']

# %% [markdown]
# ### Ödev 3
#
# Enumerate methodunu araştırın ve aşağıdaki örneği enumerate methodu ile yapın.

# %%
meyveler =["elma" , "armut" , "çilek"]
for index,meyve in enumerate(meyveler,0 ):

    print("{}. indexte bulunan meyve: {}".format(index,meyve))
# Out:
# 0. indexte bulunan meyve: elma
# 1. indexte bulunan meyve: armut
# 2. indexte bulunan meyve: çilek

# %% [markdown]
# ## Sozluk

# %% [markdown]
# 1. Bir sözlük oluşturulur ve bu sözlükte öğrencilerin isimleri ve Matematik, Fizik, Kimya notları tutulur. Kullanıcıdan isim ve ders ismi(Matematik, Fizik, Kimya) istenir ve bu bilgilere göre çıktı verilir.

# %%
isim = input("Öğrenci adı: ")
ders = input("Ders adı (Matematik, Fizik, Kimya): ")

notlar = {
    "ahmet": {"Matematik": 85, "Fizik": 78, "Kimya": 92},
    "ayşe": {"Matematik": 90, "Fizik": 88, "Kimya": 81},
    "mehmet": {"Matematik": 75, "Fizik": 70, "Kimya": 60},
}

if isim in notlar:
    if ders in notlar[isim]:
        print(f"{isim} adlı öğrencinin {ders} notu: {notlar[isim][ders]}")
    else:
        print("Bu ders bulunamadı!")
else:
    print("Öğrenci bulunamadı!")
# Out:
# Öğrenci adı: ahmet
# Ders adı (Matematik, Fizik, Kimya): matematik
# Bu ders bulunamadı!

# %% [markdown]
# 2. Sözlük üzerinde değerleri değiştirme, yeni değer ekleme, kullanıcıya ulaşmak istediği bilgileri sorma gibi uygulamalar yapın.

# %%
isim = input("Öğrenci adı: ")
ders = input("Ders adı (Matematik, Fizik, Kimya): ")

notlar = {
    "ahmet": {"Matematik": 85, "Fizik": 78, "Kimya": 92},
    "ayşe": {"Matematik": 90, "Fizik": 88, "Kimya": 81},
    "mehmet": {"Matematik": 75, "Fizik": 70, "Kimya": 60},
}

yeni_not = int(input("Yeni notu girin: "))

notlar[isim][ders] = yeni_not
print(f"{isim} - {ders} notu güncellendi.Yeni notu:{yeni_not}")
# Out:
# Öğrenci adı: ayşe
# Ders adı (Matematik, Fizik, Kimya): Fizik
# Yeni notu girin: 35
# ayşe - Fizik notu güncellendi.Yeni notu:35

# %%
notlar = {
    "ahmet": {"Matematik": 85, "Fizik": 78, "Kimya": 92},
    "ayşe": {"Matematik": 90, "Fizik": 88, "Kimya": 81},
    "mehmet": {"Matematik": 75, "Fizik": 70, "Kimya": 60},
}

notlar['ayşe']['Fizik'] = 25
print(notlar['ayşe']['Fizik'])
# Out:
# 25
